# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("AB_NYC_2019.csv")
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.price.describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
df.price.quantile(0.75)
# Out:
# 175.0

# %%
df.price.quantile(0.75, interpolation ="higher")
# Out:
# 175

# %%
percentile_1, percentile_99 = df.price.quantile([0.01,0.999])
percentile_1, percentile_99
# Out:
# (30.0, 3000.0)

# %%
df[df.price<=percentile_1]
# Out:
#              id                                             name    host_id  \
# 776      278145               Large Room in a Huge NY apartment.    1452026
# 845      296844                  HISTORIC WILLIAMSBURG, BKLYN #1     839679
# 957      375249                  Enjoy Staten Island Hospitality    1887999
# 1965     858695              Very Large Private Room on quiet st    4494343
# 2062     924658              Bright, airy room share in Brooklyn    4973668
# ...         ...                                              ...        ...
# 48665  36374141  Sunny Bedroom with renovated rooftop + balcony!   37872024
# 48832  36450814                         FLATBUSH HANG OUT AND GO  267223765
# 48852  36455809          Cozy Private Room in Bushwick, Brooklyn   74162901
# 48867  36473044  The place you were dreaming for.(only for guys)  261338177
# 48868  36473253                     Heaven for you(only for guy)  261338177
#
# ...

# %%
df2 = df[(df.price>=percentile_1)&(df.price<=percentile_99)]
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df2 = df[(df.price>=percentile_1)&(df.price<=percentile_99)]
#       2 df2
#
# NameError: name 'df' is not defined

# %%
df2.sample(5)
# Out:
#              id                                        name   host_id  \
# 9699    7457673                NEW Modern Brooklyn 1BR Apt!   2203415
# 13080   9900120          Bedroom built for... just sleeping  50914877
# 44159  34081178  Central Park-Time Square-All Major Subways   2161203
# 14676  11591364          Heart of Williamsburg, Floor thru!   2487433
# 43951  33964014                                The Zen Home  15853933
#
#       host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 9699      James            Brooklyn  Bedford-Stuyvesant  40.68678  -73.95130
# 13080      Kyle           Manhattan              Harlem  40.81850  -73.94420
# 44159   Bassema           Manhattan      Hell's Kitchen  40.76601  -73.98414
# 14676   Octavio            Brooklyn        Williamsburg  40.71826  -73.95795
# 43951  Radilena              Queens             Astoria  40.76623  -73.91243
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df2.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df2.describe()
#
# NameError: name 'df2' is not defined
